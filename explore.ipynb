# %%
import pandas as pd
df = pd.read_csv('tmp/housing_data_silver.csv')
df.head(20) # This will render a beautiful, scrollable table
# Out:
# C:\Users\jsing\AppData\Local\Temp\ipykernel_22780\931776707.py:2: DtypeWarning: Columns (0: Series_title_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('tmp/housing_data_silver.csv')
#    Series_reference      Period  Data_value STATUS  UNITS  \
# 0         CEPQ.S611  1989-12-01  456.670842  FINAL  Index
# 1         CEPQ.S611  1990-03-01  458.954197  FINAL  Index
# 2         CEPQ.S611  1990-06-01  466.717601  FINAL  Index
# 3         CEPQ.S611  1990-09-01  462.607563  FINAL  Index
# 4         CEPQ.S611  1990-12-01  467.174272  FINAL  Index
# 5         CEPQ.S611  1991-03-01  471.284309  FINAL  Index
# 6         CEPQ.S611  1991-06-01  474.024334  FINAL  Index
# 7         CEPQ.S611  1991-09-01  474.937676  FINAL  Index
# 8         CEPQ.S611  1991-12-01  478.134372  FINAL  Index
# 9         CEPQ.S611  1992-03-01  483.157751  FINAL  Index
# 10        CEPQ.S611  1992-06-01  485.897776  FINAL  Index
# ...
